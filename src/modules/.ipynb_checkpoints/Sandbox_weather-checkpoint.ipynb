# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
#Create local file to avoid issue with library
from pathlib import Path

# %%
#Got airports from table flights
df_airports = pd.read_csv("../../data/raw/airportsFlightsTable.csv")
df_airports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 376 entries, 0 to 375
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   airport_id  376 non-null    int64
#  1   iata_code   376 non-null    object
#  2   city        376 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 8.9+ KB

# %%
#Got airports from https://ourairports.com/airports.html
global_airports = pd.read_csv("../../data/raw/worldAirports.csv")

# %%
df_global_airports = global_airports[['ident','iata_code','latitude_deg','longitude_deg']]
df_global_airports.rename(columns={'latitude_deg': 'lat','longitude_deg':'lon'}, inplace = True)
df_global_airports
# Out:
#       ident iata_code        lat         lon
# 0      EGLL       LHR  51.470600   -0.461941
# 1      KLAX       LAX  33.942501 -118.407997
# 2      KORD       ORD  41.978600  -87.904800
# 3      KJFK       JFK  40.639447  -73.779317
# 4      KATL       ATL  33.636700  -84.428101
# ...     ...       ...        ...         ...
# 35484  CMB7       NaN  45.253000  -74.807000
# 35485  12CN       NaN  39.268306 -122.116689
# 35486  8CL6       NaN  39.288502 -122.189003
# 35487  0ID2       NaN  44.442902 -113.773003
# 35488   0U8       NaN  44.610199 -113.896004
#
# [35489 rows x 4 columns]

# %%
df_airports_merged = df_airports.merge(df_global_airports, on = 'iata_code', how = 'inner' )
df_airports_merged = df_airports_merged.drop(columns=['city','ident'])
df_airports_merged['Key'] = df_airports_merged['lat'].astype(str) +'-'+df_airports_merged['lat'].astype(str)
df_airports_merged
# Out:
#      airport_id iata_code        lat         lon  \
# 0         10135       ABE  40.651773  -75.442797
# 1         10136       ABI  32.411301  -99.681900
# 2         10140       ABQ  35.040199 -106.609001
# 3         10141       ABR  45.449100  -98.421799
# 4         10146       ABY  31.532946  -84.196215
# ..          ...       ...        ...         ...
# 369       15991       YAK  59.508717 -139.660435
# 370       16101       YKM  46.568199 -120.543999
# 371       16133       YNG  41.260700  -80.679100
# 372       16218       YUM  32.656601 -114.606003
# 373       16869       XWA  48.258387 -103.748797
#
#                                        Key
# 0                      40.651773-40.651773
# 1              32.4113006592-32.4113006592
# 2                      35.040199-35.040199
# 3    45.449100494384766-45.449100494384766
# 4                      31.532946-31.532946
# ..                                     ...
# 369                    59.508717-59.508717
# 370                46.56819916-46.56819916
# 371                41.26070023-41.26070023
# 372                    32.656601-32.656601
# 373                    48.258387-48.258387
#
# [374 rows x 5 columns]

# %%
#Create local file for airports id, iatacode, latitute and longitude
from pathlib import Path  
filepath = Path('../../data/raw/Airports_lat_lon.csv')  
filepath.parent.mkdir(parents=True, exist_ok=True)  
df_airports_merged.to_csv(filepath)

# %%
# pip install meteostat

# %%
#Import meteostast library and datetime
from datetime import datetime
from meteostat import Point, Daily

start = datetime(2018, 1, 1) # Change start date
end = datetime(2020, 1, 31) # Change end date

# %%
#use weather library meteostat
#Be carefull this library is not availble all the time and generate connection errors
#def get_bulk_weather(df):
#    weather_dfs=[]
#    for i,r in df.iterrows():
#        point = Point(r.lat, r.lon)
#        data = Daily(point, start, end)
#        data = data.fetch()
#        data["lat"] = r.lat
#        data["lon"] = r.lon
#        weather_dfs.append(data)
#    weather_final = pd.concat(weather_dfs)
#    return weather_final 
#
#df_weather = get_bulk_weather(df_airports_merged)
#df_weather

# %%
#filepath = Path('/Users/hugo/Library/CloudStorage/OneDrive-Personal/DATA_Science/Bootcamp/W7/mid-term-project-I/data/raw/weatherAirports_2019_2018_Jan2020.csv')  
#filepath.parent.mkdir(parents=True, exist_ok=True)  
#df_weather.to_csv(filepath)

# %%
df_weather_f = pd.read_csv("../../data/processed/weatherAirports_2019_2018_Jan2020_clean.csv")  
df_weather_f
# Out:
#         Unnamed: 0     fl_date  AvgTemp  Precipitation  Snow_mm  WindSpeed  \
# 0                0  2018-01-01    -11.7            0.0     30.0       13.0
# 1                1  2018-01-02     -9.4            0.0     30.0       17.3
# 2                2  2018-01-03     -8.9            0.0      0.0        4.3
# 3                3  2018-01-04     -5.0            2.5      0.0       24.5
# 4                4  2018-01-05    -10.8            0.0     30.0       29.9
# ...            ...         ...      ...            ...      ...        ...
# 271661      271661  2019-12-25      0.0            0.0      0.0        0.0
# 271662      271662  2019-12-26      0.0            0.0      0.0        0.0
# 271663      271663  2019-12-27      0.0            0.0      0.0        0.0
# 271664      271664  2019-12-28      0.0            0.0      0.0        0.0
# 271665      271665  2019-12-29      0.0            0.0      0.0        0.0
#
#               lat         lon                  Key
# 0       40.651773  -75.442797  40.651773-40.651773
# 1       40.651773  -75.442797  40.651773-40.651773
# 2       40.651773  -75.442797  40.651773-40.651773
# 3       40.651773  -75.442797  40.651773-40.651773
# 4       40.651773  -75.442797  40.651773-40.651773
# ...           ...         ...                  ...
# 271661  48.258387 -103.748797  48.258387-48.258387
# 271662  48.258387 -103.748797  48.258387-48.258387
# 271663  48.258387 -103.748797  48.258387-48.258387
# 271664  48.258387 -103.748797  48.258387-48.258387
# 271665  48.258387 -103.748797  48.258387-48.258387
#
# [271666 rows x 9 columns]

# %%
# df_weather_f = df_weather_f.drop(columns=['tmin','tmax','wdir','pres','wpgt','tsun']) 
df_weather_f.rename(columns={'Unnamed: 0' :'fl_date','tavg':'AvgTemp', 'prcp':'Precipitation', 'snow':'Snow_mm','wspd':'WindSpeed'}, inplace=True)
df_weather_f['Key'] = df_weather_f['lat'].astype(str) +'-'+df_weather_f['lat'].astype(str)

# %%
df_weather_f.fillna(0, inplace=True)
#df_weather_f.drop_duplicates(inplace=True)
df_weather_f
# Out:
#        fl_date     fl_date  AvgTemp  Precipitation  Snow_mm  WindSpeed  \
# 0            0  2018-01-01    -11.7            0.0     30.0       13.0
# 1            1  2018-01-02     -9.4            0.0     30.0       17.3
# 2            2  2018-01-03     -8.9            0.0      0.0        4.3
# 3            3  2018-01-04     -5.0            2.5      0.0       24.5
# 4            4  2018-01-05    -10.8            0.0     30.0       29.9
# ...        ...         ...      ...            ...      ...        ...
# 271661  271661  2019-12-25      0.0            0.0      0.0        0.0
# 271662  271662  2019-12-26      0.0            0.0      0.0        0.0
# 271663  271663  2019-12-27      0.0            0.0      0.0        0.0
# 271664  271664  2019-12-28      0.0            0.0      0.0        0.0
# 271665  271665  2019-12-29      0.0            0.0      0.0        0.0
#
#               lat         lon                  Key
# 0       40.651773  -75.442797  40.651773-40.651773
# 1       40.651773  -75.442797  40.651773-40.651773
# 2       40.651773  -75.442797  40.651773-40.651773
# 3       40.651773  -75.442797  40.651773-40.651773
# 4       40.651773  -75.442797  40.651773-40.651773
# ...           ...         ...                  ...
# 271661  48.258387 -103.748797  48.258387-48.258387
# 271662  48.258387 -103.748797  48.258387-48.258387
# 271663  48.258387 -103.748797  48.258387-48.258387
# 271664  48.258387 -103.748797  48.258387-48.258387
# 271665  48.258387 -103.748797  48.258387-48.258387
#
# [271666 rows x 9 columns]

# %%
#filepath = Path('/Users/hugo/Library/CloudStorage/OneDrive-Personal/DATA_Science/Bootcamp/W7/mid-term-project-I/data/processed/weatherAirports_2019_2018_Jan2020_clean.csv')  
#filepath.parent.mkdir(parents=True, exist_ok=True)  
#df_weather_f.to_csv(filepath)

# %% [markdown]
# ## Model Data Transformation

# %%
model_data = pd.read_csv("../../data/raw/random_sample_flight_data.csv")
model_data
# Out:
#        op_carrier_fl_num op_unique_carrier  origin_airport_id  \
# 0                   1610                UA              11618
# 1                   1519                UA              10800
# 2                   5452                OO              14487
# 3                   1054                B6              14027
# 4                    790                UA              13930
# ...                  ...               ...                ...
# 99995               6279                YV              12266
# 99996               2047                UA              12266
# 99997               7406                OO              11433
# 99998               5151                OH              12323
# 99999               2245                DL              10397
#
#        dest_airport_id  distance        route  month  day    fl_date  \
# 0                13495      1167  11618-13495      3    1 2019-03-01
# 1                11292       850  10800-11292      7   19 2019-07-19
# 2                14771       199  14487-14771      6   25 2018-06-25
# 3                12478      1028  14027-12478     11   30 2018-11-30
# 4                10721       867  13930-10721      3   26 2019-03-26
# ...                ...       ...          ...    ...  ...        ...
# 99995            10994       925  12266-10994      7   31 2018-07-31
# 99996            10721      1597  12266-10721     12   31 2018-12-31
# 99997            13459       349  11433-13459      7   22 2018-07-22
# 99998            11057       185  12323-11057      3    5 2019-03-05
# 99999            10423       813  10397-10423      2   17 2019-02-17
#
#        arr_delay
# 0            0.0
# 1           -5.0
# 2          119.0
# 3            3.0
# 4           -8.0
# ...          ...
# 99995      226.0
# 99996      -37.0
# 99997      -22.0
# 99998      109.0
# 99999       -2.0
#
# [100000 rows x 10 columns]

# %%
def model_data_transformation(model_data):
    #call functions for data merging
    from add_location_weather import add_location
    
    #import datasets to merge with model data and do a little cleaning
    model_data['fl_date'] = model_data['fl_date'].astype('datetime64')
    airports_ids =  pd.read_csv("../../data/processed/Airports_lat_lon.csv")
    airports_ids = airports_ids.drop(['Unnamed: 0'], axis=1)
    weather_airports = pd.read_csv("../../data/processed/weatherAirports_2019_2018_Jan2020_clean.csv")
    weather_airports['fl_date'] = weather_airports['fl_date'].astype('datetime64')
    weather_airports = weather_airports.drop(['Unnamed: 0'], axis=1)
    
    #merge model data with airport ids and drop data that will be unnecesary to the model 
    df = add_location(model_data,airports_ids)
    df = df.drop(['airport_id','iata_code','lat','lon'], axis=1)
    
    #merge the flight & airport data with the weather data
    df1 = pd.merge(df,weather_airports, on = ['Key','fl_date'], how ='left')
    df1.drop_duplicates(inplace=True)
    
    # transform categorical variables in numeric with LabelEncoder
    from sklearn.preprocessing import LabelEncoder
    le = LabelEncoder()

    # fit and transform the data
    df1['op_unique_carrier'] = le.fit_transform(df1['op_unique_carrier'])
    df1['route'] = le.fit_transform(df1['route'])

    # drop rows with missing values
    df1 = df1.dropna().reset_index(drop=True)
    
    return(df1)

# %%
transformed_model_flight_df = model_data_transformation(model_data)
transformed_model_flight_df
# Out:
#        op_carrier_fl_num  op_unique_carrier  origin_airport_id  \
# 0                   1610                 22              11618
# 1                   4909                  6              11618
# 2                   3556                 26              11618
# 3                   1382                  2              11618
# 4                   3517                 26              11618
# ...                  ...                ...                ...
# 97302               5026                 19              11092
# 97303               5031                 19              11092
# 97304               5079                 19              11092
# 97305               5031                 19              11092
# 97306                865                 12              12119
#
#        dest_airport_id  distance  route  month  day    fl_date  arr_delay  \
# 0                13495      1167   1962      3    1 2019-03-01        0.0
# 1                14524       277   1978     12    6 2019-12-06      -17.0
# 2                11193       569   1928      4    3 2018-04-03       -9.0
# 3                11298      1372   1932      9    7 2019-09-07       68.0
# 4                13495      1167   1962      2    5 2018-02-05      -37.0
# ...                ...       ...    ...    ...  ...        ...        ...
# 97302            11292       283   1111      9   22 2019-09-22        0.0
# 97303            11292       283   1111      8   10 2019-08-10      -12.0
# 97304            11292       283   1111      8   15 2018-08-15        2.0
# 97305            11292       283   1111      5   26 2019-05-26      -22.0
# 97306            14112       861   2279      7   15 2018-07-15      105.0
#
#                            Key  AvgTemp  Precipitation  Snow_mm  WindSpeed  \
# 0          40.692501-40.692501      0.8            1.3     30.0       15.9
# 1          40.692501-40.692501      5.7            0.0      0.0       12.2
# 2          40.692501-40.692501      4.9            5.8     30.0       11.1
# 3          40.692501-40.692501     20.4            0.0      0.0        6.3
# 4          40.692501-40.692501      0.3            0.0      0.0       13.4
# ...                        ...      ...            ...      ...        ...
# 97302  38.75500107-38.75500107     16.0            0.0      0.0        0.0
# 97303  38.75500107-38.75500107     27.3            0.0      0.0        0.0
# 97304  38.75500107-38.75500107     28.5            0.0      0.0       10.7
# 97305  38.75500107-38.75500107     18.3            0.0      0.0       11.4
# 97306      39.707901-39.707901     26.7            0.0      0.0        9.1
#
#              lat         lon
# 0      40.692501  -74.168701
# 1      40.692501  -74.168701
# 2      40.692501  -74.168701
# 3      40.692501  -74.168701
# 4      40.692501  -74.168701
# ...          ...         ...
# 97302  38.755001 -109.754997
# 97303  38.755001 -109.754997
# 97304  38.755001 -109.754997
# 97305  38.755001 -109.754997
# 97306  39.707901  -77.729500
#
# [97307 rows x 17 columns]

# %%
transformed_model_flight_df.to_csv('../../data/processed/transformed_model_flight_data.csv', index=False)

# %%
# from add_location_weather import add_location
# from add_location_weather import add_weather

# %%
# airports_ids =  pd.read_csv("../../data/processed/Airports_lat_lon.csv")
# airports_ids = airports_ids.drop(['Unnamed: 0'], axis=1)
# airports_ids

# %%
# df = add_location(model_data,airports_ids)
# df = df.drop(['airport_id','iata_code','lat','lon'], axis=1)
# df

# %%
# weather_airports = pd.read_csv("../../data/processed/weatherAirports_2019_2018_Jan2020_clean.csv")
# weather_airports = weather_airports.drop(['Unnamed: 0'], axis=1)
# weather_airports['fl_date'] = weather_airports['fl_date'].astype('datetime64')
# weather_airports

# %%
# df1 = pd.merge(df,weather_airports, on = ['Key','fl_date'], how ='left')
# df1.drop_duplicates(inplace=True)
# df1

# %%
# from sklearn.preprocessing import LabelEncoder

# # initialize LabelEncoder
# le = LabelEncoder()

# # fit and transform the data
# df1['op_unique_carrier'] = le.fit_transform(df1['op_unique_carrier'])
# df1['route'] = le.fit_transform(df1['route'])
# df1

# %%
# df1.columns.tolist()

# %%
# # drop rows with missing values
# df1 = df1.dropna().reset_index(drop=True)
# df1.shape

# %% [markdown]
# ## Week One Transformed Test Data

# %%
df_week_one  = pd.read_csv("../../data/raw/Week_one_data_10000.csv")
df_week_one
# Out:
#       op_carrier_fl_num op_unique_carrier  origin_airport_id  dest_airport_id  \
# 0                  5390                WN              14057            11292
# 1                  2331                WN              15376            11292
# 2                  2321                NK              14843            11618
# 3                  5496                OO              11109            12266
# 4                  2811                QX              11884            14057
# ...                 ...               ...                ...              ...
# 9995               1447                DL              12953            10397
# 9996                167                NK              10821            14492
# 9997               1037                UA              11618            11298
# 9998               6130                YX              14122            12953
# 9999                772                AS              14679            11618
#
#       distance        route  day
# 0        991.0  14057-11292    1
# 1        639.0  15376-11292    2
# 2       1608.0  14843-11618    5
# 3        809.0  11109-12266    3
# 4        279.0  11884-14057    3
# ...        ...          ...  ...
# 9995     762.0  12953-10397    2
# 9996     255.0  10821-14492    4
# 9997    1372.0  11618-11298    7
# 9998     335.0  14122-12953    3
# 9999    2425.0  14679-11618    4
#
# [10000 rows x 7 columns]

# %%
def week_one_data_transformation(df_week_one):
    #call functions for data merging
    from add_location_weather import add_location
    from add_location_weather import add_weather
    
    #import datasets to merge with test data
    airports_ids =  pd.read_csv("../../data/processed/Airports_lat_lon.csv")
    airports_ids = airports_ids.drop(['Unnamed: 0'], axis=1)
    weather_airports = pd.read_csv("../../data/processed/weatherAirports_2019_2018_Jan2020_clean.csv")
    weather_airports = weather_airports.drop(['Unnamed: 0'], axis=1)
    
    #merge week one test data with airport ids and drop data that will be unnecesary to the model    
    df = add_location(df_week_one,airports_ids)
    df = df.drop(['airport_id','iata_code','lat','lon'], axis=1)
    
    #merge the flight & airport data with the weather data
    df1= add_weather(df,weather_airports)
    
    #get month data out of fl_date
    import datetime
    df1['Month'] = df1['fl_date'].dt.month
    
    # transform categorical variables in numeric with LabelEncoder
    from sklearn.preprocessing import LabelEncoder
    le = LabelEncoder()

    # fit and transform the data
    df1['op_unique_carrier'] = le.fit_transform(df1['op_unique_carrier'])
    df1['route'] = le.fit_transform(df1['route'])

    # drop rows with missing values
    df1 = df1.dropna().reset_index(drop=True)
    
    return(df1)

# %%
df_transformed_week1_2020 = week_one_data_transformation(df_week_one)
df_transformed_week1_2020
# Out:
#       op_carrier_fl_num  op_unique_carrier  origin_airport_id  \
# 0                  5390                 21              14057
# 1                  5752                  6              14057
# 2                   789                 20              14057
# 3                  1184                  2              14057
# 4                  1552                  2              14057
# ...                 ...                ...                ...
# 9911               5147                 17              14006
# 9912               5081                 17              13121
# 9913               3845                 14              11905
# 9914               4258                 17              12003
# 9915               4275                 17              14150
#
#       dest_airport_id  distance  route  day  \
# 0               11292     991.0   2737    1
# 1               14747     129.0   2764    7
# 2               11292     991.0   2737    2
# 3               14679     933.0   2763    7
# 4               14262     873.0   2760    7
# ...               ...       ...    ...  ...
# 9911            13930     342.0   2708    6
# 9912            13930     489.0   2064    2
# 9913            11298     140.0   1419    2
# 9914            14869     463.0   1466    6
# 9915            11433     243.0   2975    3
#
#                                       Key    fl_date  AvgTemp  Precipitation  \
# 0                 45.58869934-45.58869934 2020-01-01     10.8            3.8
# 1                 45.58869934-45.58869934 2020-01-07     11.3            2.8
# 2                 45.58869934-45.58869934 2020-01-02      8.2            1.0
# 3                 45.58869934-45.58869934 2020-01-07     11.3            2.8
# 4                 45.58869934-45.58869934 2020-01-07     11.3            2.8
# ...                                   ...        ...      ...            ...
# 9911  37.06079864501953-37.06079864501953 2020-01-06      5.3            0.0
# 9912          37.8582992554-37.8582992554 2020-01-02      1.9            0.0
# 9913  32.38399887084961-32.38399887084961 2020-01-02     12.1            4.6
# 9914              47.48199844-47.48199844 2020-01-06      0.1            0.0
# 9915              45.57089996-45.57089996 2020-01-03      0.5            0.0
#
#       Snow_mm  WindSpeed        lat         lon  Month
# 0         0.0       11.9  45.588699 -122.598000      1
# 1         0.0       24.8  45.588699 -122.598000      1
# 2         0.0       11.9  45.588699 -122.598000      1
# 3         0.0       24.8  45.588699 -122.598000      1
# 4         0.0       24.8  45.588699 -122.598000      1
# ...       ...        ...        ...         ...    ...
# 9911      0.0        7.9  37.060799  -88.773804      1
# 9912      0.0        1.8  37.858299  -80.399498      1
# 9913      0.0       11.9  32.383999  -94.711502      1
# 9914      0.0       26.3  47.481998 -111.371002      1
# 9915      0.0       13.5  45.570900  -84.796700      1
#
# [9916 rows x 16 columns]

# %%
df_transformed_week1_2020.to_csv('../../data/processed/transformed_week1_2020.csv', index=False)

# %%
# df = add_location(df_week_one,airports_ids)
# df = df.drop(['airport_id','iata_code','lat','lon'], axis=1)
# df

# %%
# df1= add_weather(df,weather_airports)
# df1

# %%
# #get month data out of fl_date
# import datetime
# df1['Month'] = df1['fl_date'].dt.month

# # drop rows with missing values
# df1 = df1.dropna().reset_index(drop=True)
# df1.shape
# df1

# %%
# from sklearn.preprocessing import LabelEncoder

# # initialize LabelEncoder
# le = LabelEncoder()

# # fit and transform the data
# df1['op_unique_carrier'] = le.fit_transform(df1['op_unique_carrier'])
# df1['route'] = le.fit_transform(df1['route'])
# df1
